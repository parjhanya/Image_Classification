# %% [markdown]
# <a href="https://colab.research.google.com/github/parjhanya/Image_Classification/blob/master/Test%20Vino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -uq "/content/drive/My Drive/Image Classification/train.zip" -d "/content/drive/My Drive/Image Classification/"

# %%
def unrar(dpath,xpath):
  for rar in os.listdir(dpath):
    filepath = os.path.join(dpath, rar)
    with rarfile.RarFile(filepath) as opened_rar:
      for f in opened_rar.infolist():
        print (f.filename, f.file_size)
        opened_rar.extractall(xpath)

unrar(/content/drive/My Drive/Image Classification/train.zip,/content/drive/My Drive/Image Classification)
# Out:
#   File "<ipython-input-16-10eef55934ae>", line 9
#     unrar(/content/drive/My Drive/Image Classification/train.zip,/content/drive/My Drive/Image Classification)
#           ^
# SyntaxError: invalid syntax

# %%
# !unzip '/content/drive/My Drive/Image Classification/train.zip' -d '/content/drive/My Drive/Image Classification/Extracted'
# Out:
# Archive:  /content/drive/My Drive/Image Classification/train.zip
#    creating: /content/drive/My Drive/Image Classification/Extracted/train/
#  extracting: /content/drive/My Drive/Image Classification/Extracted/train/train.7z
#   inflating: /content/drive/My Drive/Image Classification/Extracted/train/trainLabels.csv

# %%
# !p7zip -d '/content/drive/My Drive/Image Classification/Extracted/train/train.7z'
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 109723070 bytes (105 MiB)
#
# Extracting archive: /content/drive/My Drive/Image Classification/Extracted/train/train.7z
# --
# Path = /content/drive/My Drive/Image Classification/Extracted/train/train.7z
# Type = 7z
# Physical Size = 109723070
# Headers Size = 294768
# Method = LZMA:26
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 50000
# Size:       112650757
# Compressed: 109723070

# %%
# !unzip '/content/drive/My Drive/Image Classification/object-recognition-test-data.zip' -d '/content/drive/My Drive/Image Classification/Extracted'
# Out:
# Archive:  /content/drive/My Drive/Image Classification/object-recognition-test-data.zip
# replace /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/178.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/178.jpg
#   inflating: /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/177.jpg
#   inflating: /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/176.jpg
#   inflating: /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/175.jpg
#   inflating: /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/174.jpg
#   inflating: /content/drive/My Drive/Image Classification/Extracted/Object_classification_test_data/173.jpg
# ...
